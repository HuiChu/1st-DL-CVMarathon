# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.243
# The Mean absolute error is 11.491

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# 資料為「Coffee Quality database from CQI」，資料提供者為Github 上的 [jldbc](https://github.com/jldbc/coffee-quality-database.html)。
# 作者蒐集從Coffee Quality Institute網站上受過專業訓練的咖啡豆評論師的評論，原始資料形式是使用者自行key in，因此爬下來後還需大量的資料清洗、整理，相關程式碼也有在作者的Github上。整理過後有三類變項：
# 1) 咖啡豆品質分數
# 全為數值變項，為評論師針對這支豆子的乾香、溼香、質地、尾韻、酸值、甜度、瑕疵等評分，區間為0~10。
#
# 2) 咖啡豆資訊
# 為類別變項，包括生豆處理法、生豆顏色與豆種。
#
# 3) 莊園資訊
# 有數值也有類別變項，有莊園名稱、主人、地區與海拔等變項。
#
# 透過這組資料，可以探討咖啡豆的流行趨勢，在某段時間中以哪幾種豆種、哪些地區或哪些莊園的豆子較易受評論師的好評。不同種、產區、處理法的豆子在哪些咖啡豆品質項目中易獲得高分。若為咖啡生豆經銷商，可結合上述資訊加上本身對咖啡豆的偏好，挑選欲代理進口的豆子，預測哪幾支豆子可能廣受大眾喜愛。若為莊園主人，則可評估近年來的趨勢，除了保留本身莊園的優勢豆種外，也能嘗試新的豆種、地區種植、處理法。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 經營一個自由載客車隊，核心問題為「如何在有效益的狀況下提高載客量」。
# 假設經營模式類似uber，是透過手機app來訂車，每次訂車紀錄都會留下：預定人基本資訊（性別、年齡區間、載客人數）、預定時間、預定地點及目的地和路程時間、花費與距離、司機性別、司機的車種。
# 將所有資料搜集（可能爬蟲）下來，可以分析哪些地點是熱門叫車區？哪些時段需求量較高？預定人的年齡族群？偏好的車種？
# 可以訓練模型，分析哪些變項對載客量影響較大，藉此預測何時何地需要多少車子在附近等待，結合google map後考量交通路況，有效率的安排動線，減少空車浪費。
# 根據預測結果派車後，再收集選定的時段、地區內的訂車紀錄，以此資料丟入訓練的模型中，並與先前預測結果比較。可以設定一個時間區間，一次次修改、調整模型設計。
# 不同地區也要妥善劃分，考慮到有些地方交通較便利，需求可能較少；需要自行開車前往的地區，且可能攜帶不少東西（例如賣場），需求可能較高。不同地區需要建立各自的模型。
